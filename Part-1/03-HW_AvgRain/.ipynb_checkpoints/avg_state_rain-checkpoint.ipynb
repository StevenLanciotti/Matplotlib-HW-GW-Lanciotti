# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='b', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1999.9999742250188">
# ([<matplotlib.axis.XTick at 0x25ab84c88d0>,
#   <matplotlib.axis.XTick at 0x25ab739dc50>,
#   <matplotlib.axis.XTick at 0x25ab84c83c8>,
#   <matplotlib.axis.XTick at 0x25ab85b8b38>,
#   <matplotlib.axis.XTick at 0x25ab85b8d30>,
#   <matplotlib.axis.XTick at 0x25ab85c6390>,
#   <matplotlib.axis.XTick at 0x25ab85c6860>,
#   <matplotlib.axis.XTick at 0x25ab85c6d30>,
#   <matplotlib.axis.XTick at 0x25ab85ce240>,
#   <matplotlib.axis.XTick at 0x25ab85ce710>,
#   <matplotlib.axis.XTick at 0x25ab85cebe0>,
#   <matplotlib.axis.XTick at 0x25ab85d5160>,
#   <matplotlib.axis.XTick at 0x25ab85d55c0>,
#   <matplotlib.axis.XTick at 0x25ab85d5a90>,
#   <matplotlib.axis.XTick at 0x25ab85cea58>,
#   <matplotlib.axis.XTick at 0x25ab85c6438>,
#   <matplotlib.axis.XTick at 0x25ab85d5198>,
#   <matplotlib.axis.XTick at 0x25ab85df240>,
#   <matplotlib.axis.XTick at 0x25ab85df710>,
#   <matplotlib.axis.XTick at 0x25ab85dfbe0>,
#   <matplotlib.axis.XTick at 0x25ab85e6160>,
#   <matplotlib.axis.XTick at 0x25ab85e65c0>,
#   <matplotlib.axis.XTick at 0x25ab85e6a90>,
#   <matplotlib.axis.XTick at 0x25ab85e6f60>,
#   <matplotlib.axis.XTick at 0x25ab85e6588>,
#   <matplotlib.axis.XTick at 0x25ab85d50b8>,
#   <matplotlib.axis.XTick at 0x25ab85ee2b0>,
#   <matplotlib.axis.XTick at 0x25ab85ee7f0>,
#   <matplotlib.axis.XTick at 0x25ab85eed68>,
#   <matplotlib.axis.XTick at 0x25ab85f5320>,
#   <matplotlib.axis.XTick at 0x25ab85f5898>,
#   <matplotlib.axis.XTick at 0x25ab85f5e10>,
#   <matplotlib.axis.XTick at 0x25ab85fc3c8>,
#   <matplotlib.axis.XTick at 0x25ab85f5978>,
#   <matplotlib.axis.XTick at 0x25ab85ce860>,
#   <matplotlib.axis.XTick at 0x25ab85fc860>,
#   <matplotlib.axis.XTick at 0x25ab85fcdd8>,
#   <matplotlib.axis.XTick at 0x25ab8603390>,
#   <matplotlib.axis.XTick at 0x25ab8603908>,
#   <matplotlib.axis.XTick at 0x25ab8603e80>,
#   <matplotlib.axis.XTick at 0x25ab860a438>,
#   <matplotlib.axis.XTick at 0x25ab860a9b0>,
#   <matplotlib.axis.XTick at 0x25ab860af28>,
#   <matplotlib.axis.XTick at 0x25ab86039b0>,
#   <matplotlib.axis.XTick at 0x25ab85fc940>,
#   <matplotlib.axis.XTick at 0x25ab86120b8>,
#   <matplotlib.axis.XTick at 0x25ab8612668>,
#   <matplotlib.axis.XTick at 0x25ab8612be0>,
#   <matplotlib.axis.XTick at 0x25ab861a198>,
#   <matplotlib.axis.XTick at 0x25ab861a710>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(401.486116707325, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/avg_state_rain_output.png")
plt.show()
